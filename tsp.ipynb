# %%
from itertools import combinations
import pandas as pd
import numpy as np
from geopy.distance import geodesic
import networkx as nx
import random

from icecream import ic
from dataclasses import dataclass
from tqdm import tqdm
import logging

# %%
countries = ['Russia', 'Italy', 'Vanuatu', 'China', 'US']

def init(country):
    global CITIES, DIST_MATRIX
    # Load cities data
    CITIES = pd.read_csv(f'{country}.csv'.lower(), header=None, names=['name', 'lat', 'lon'])

    # Create distance matrix
    DIST_MATRIX = np.zeros((len(CITIES), len(CITIES)))
    for c1, c2 in combinations(CITIES.itertuples(), 2):
        DIST_MATRIX[c1.Index, c2.Index] = DIST_MATRIX[c2.Index, c1.Index] = geodesic(
            (c1.lat, c1.lon), (c2.lat, c2.lon)
        ).km
    

def compute_tour_distance(path, distance_matrix):
    total_distance = 0.0
    for i in range(len(path) - 1):
        #city_from = path[i]
        #city_to = path[i + 1]
        total_distance += distance_matrix[path[i]][path[i + 1]]
    return total_distance

# %%
def tsp_cost(tsp):
    assert tsp[0] == tsp[-1]
    assert set(tsp) == set(range(len(CITIES)))

    tot_cost = 0
    for c1, c2 in zip(tsp, tsp[1:]):
        tot_cost += DIST_MATRIX[c1, c2]
    return tot_cost

# %% [markdown]
# ## First Greedy Algorithm: nearest neighbor

# %%
for country in countries:

    init(country)
    print(country)

    visited = np.full(len(CITIES), False)
    dist = DIST_MATRIX.copy()
    city = 0
    visited[city] = True
    tsp = list()
    tsp.append(int(city))
    while not np.all(visited):
        dist[:, city] = np.inf
        closest = np.argmin(dist[city])
        print(f"step: {CITIES.at[city,'name']} -> {CITIES.at[closest,'name']} ({DIST_MATRIX[city,closest]:.2f}km)")
        visited[closest] = True
        city = closest
        tsp.append(int(city))
    print(f"step: {CITIES.at[tsp[-1],'name']} -> {CITIES.at[tsp[0],'name']} ({DIST_MATRIX[tsp[-1],tsp[0]]:.2f}km)")
    tsp.append(tsp[0])


    logging.info(f"{country} result: Found a path of {len(tsp)-1} steps, total length {tsp_cost(tsp):.2f}km")
# Out:
# INFO:root:Russia result: Found a path of 167 steps, total length 42334.16km
# INFO:root:Italy result: Found a path of 46 steps, total length 4436.03km
# INFO:root:Vanuatu result: Found a path of 8 steps, total length 1475.53km
# Russia
# step: Abakan -> Krasnoyarsk (276.58km)
# step: Krasnoyarsk -> Achinsk (161.71km)
# step: Achinsk -> Kemerovo (296.59km)
# step: Kemerovo -> Leninsk‐Kuznetskiy (74.76km)
# step: Leninsk‐Kuznetskiy -> Prokopyevsk (91.87km)
# step: Prokopyevsk -> Novokuznetsk (30.63km)
# step: Novokuznetsk -> Biysk (187.38km)
# step: Biysk -> Barnaul (132.82km)
# step: Barnaul -> Novosibirsk (194.50km)
# step: Novosibirsk -> Tomsk (206.90km)
# step: Tomsk -> Seversk (14.97km)
# step: Seversk -> Rubtsovsk (613.13km)
# step: Rubtsovsk -> Omsk (647.47km)
# step: Omsk -> Tobolsk (475.40km)
# step: Tobolsk -> Tyumen (200.98km)
# step: Tyumen -> Kurgan (189.69km)
# step: Kurgan -> Kopeysk (236.87km)
# step: Kopeysk -> Chelyabinsk (14.72km)
# step: Chelyabinsk -> Miass (87.20km)
# step: Miass -> Zlatoust (33.88km)
# step: Zlatoust -> Pervouralsk (194.64km)
# step: Pervouralsk -> Yekaterinburg (40.19km)
# step: Yekaterinburg -> Kamensk‐Uralskiy (95.20km)
# step: Kamensk‐Uralskiy -> Nizhniy Tagil (205.75km)
# step: Nizhniy Tagil -> Perm (220.37km)
# step: Perm -> Berezniki (159.92km)
# step: Berezniki -> Izhevsk (353.17km)
# step: Izhevsk -> Neftekamsk (107.05km)
# step: Neftekamsk -> Naberezhnye Chelny (129.52km)
# step: Naberezhnye Chelny -> Nizhnekamsk (31.95km)
# step: Nizhnekamsk -> Almetyevsk (88.07km)
# step: Almetyevsk -> Oktyabrskiy (88.27km)
# step: Oktyabrskiy -> Ufa (170.17km)
# step: Ufa -> Sterlitamak (128.14km)
# step: Sterlitamak -> Salavat (29.01km)
# step: Salavat -> Orenberg (185.10km)
# step: Orenberg -> Orenburg (0.37km)
# step: Orenburg -> Novotroitsk (232.42km)
# step: Novotroitsk -> Orsk (21.66km)
# step: Orsk -> Magnitogorsk (247.00km)
# step: Magnitogorsk -> Samara (588.03km)
# step: Samara -> Novokuybyshevsk (17.80km)
# step: Novokuybyshevsk -> Tolyatti (49.80km)
# step: Tolyatti -> Syzran (77.41km)
# step: Syzran -> Ulyanovsk (129.19km)
# step: Ulyanovsk -> Dimitrovgrad (75.41km)
# step: Dimitrovgrad -> Kazan (169.13km)
# step: Kazan -> Novocheboksarsk (109.88km)
# step: Novocheboksarsk -> Cheboksary (15.59km)
# step: Cheboksary -> Yoshkar‐Ola (68.49km)
# step: Yoshkar‐Ola -> Nizhny Novgorod (240.88km)
# step: Nizhny Novgorod -> Dzerzhinsk (34.91km)
# step: Dzerzhinsk -> Arzamas (98.38km)
# step: Arzamas -> Murom (114.53km)
# step: Murom -> Kovrov (98.78km)
# step: Kovrov -> Vladimir (62.07km)
# step: Vladimir -> Orekhovo‐Zuevo (95.53km)
# step: Orekhovo‐Zuevo -> Noginsk (34.00km)
# step: Noginsk -> Elektrostal (6.68km)
# step: Elektrostal -> Zheleznodorozhnyy (26.94km)
# step: Zheleznodorozhnyy -> Balashikha (6.96km)
# step: Balashikha -> Shchyolkovo (11.97km)
# step: Shchyolkovo -> Korolyov (12.70km)
# step: Korolyov -> Mytishchi (5.74km)
# step: Mytishchi -> Khimki (18.28km)
# step: Khimki -> Zelenograd (10.91km)
# step: Zelenograd -> Moscow (29.58km)
# step: Moscow -> Lyubertsy (19.17km)
# step: Lyubertsy -> Zhukovskiy (26.33km)
# step: Zhukovskiy -> Podolsk (47.16km)
# step: Podolsk -> Odintsovo (32.00km)
# step: Odintsovo -> Obninsk (76.71km)
# step: Obninsk -> Serpukhov (54.96km)
# step: Serpukhov -> Tula (81.18km)
# step: Tula -> Novomoskovsk (41.70km)
# step: Novomoskovsk -> Ryazan (115.09km)
# step: Ryazan -> Kolomna (80.15km)
# step: Kolomna -> Sergiyev Posad (143.98km)
# step: Sergiyev Posad -> Tver (150.18km)
# step: Tver -> Rybinsk (220.67km)
# step: Rybinsk -> Yaroslavl (78.17km)
# step: Yaroslavl -> Kostroma (65.38km)
# step: Kostroma -> Ivanovo (84.72km)
# step: Ivanovo -> Vologda (254.39km)
# step: Vologda -> Cherepovets (114.80km)
# step: Cherepovets -> Petrozavodsk (358.19km)
# step: Petrozavodsk -> Saint Petersburg (302.88km)
# step: Saint Petersburg -> Kolpino (25.47km)
# step: Kolpino -> Velikiy Novgorod (142.44km)
# step: Velikiy Novgorod -> Pskov (189.82km)
# step: Pskov -> Velikie Luki (212.88km)
# step: Velikie Luki -> Smolensk (198.09km)
# step: Smolensk -> Bryansk (230.10km)
# step: Bryansk -> Oryol (115.74km)
# step: Oryol -> Kursk (138.18km)
# step: Kursk -> Staryy Oskol (124.13km)
# step: Staryy Oskol -> Voronezh (109.10km)
# step: Voronezh -> Lipetsk (103.13km)
# step: Lipetsk -> Yelets (75.22km)
# step: Yelets -> Tambov (198.07km)
# step: Tambov -> Penza (245.48km)
# step: Penza -> Saransk (109.72km)
# step: Saransk -> Balakovo (295.88km)
# step: Balakovo -> Engels (128.88km)
# step: Engels -> Saratov (9.98km)
# step: Saratov -> Kamyshin (169.44km)
# step: Kamyshin -> Volzhskiy (152.69km)
# step: Volzhskiy -> Volgograd (23.11km)
# step: Volgograd -> Volgodonsk (218.86km)
# step: Volgodonsk -> Shakhty (147.54km)
# step: Shakhty -> Novoshakhtinsk (20.74km)
# step: Novoshakhtinsk -> Novocherkassk (38.39km)
# step: Novocherkassk -> Rostov‐na‐Donu (35.01km)
# step: Rostov‐na‐Donu -> Bataysk (11.52km)
# step: Bataysk -> Taganrog (64.29km)
# step: Taganrog -> Krasnodar (243.49km)
# step: Krasnodar -> Maykop (100.83km)
# step: Maykop -> Armavir (90.38km)
# step: Armavir -> Stavropol (67.23km)
# step: Stavropol -> Nevinnomyssk (45.59km)
# step: Nevinnomyssk -> Cherkessk (38.78km)
# step: Cherkessk -> Kislovodsk (67.64km)
# step: Kislovodsk -> Pyatigorsk (31.40km)
# step: Pyatigorsk -> Nalchik (75.94km)
# step: Nalchik -> Vladikavkaz (100.08km)
# step: Vladikavkaz -> Nazran (21.26km)
# step: Nazran -> Groznyy (73.92km)
# step: Groznyy -> Khasavyurt (72.55km)
# step: Khasavyurt -> Makhachkala (79.91km)
# step: Makhachkala -> Kaspiysk (15.94km)
# step: Kaspiysk -> Derbent (105.61km)
# step: Derbent -> Astrakhan (477.07km)
# step: Astrakhan -> Elista (295.65km)
# step: Elista -> Sochi (464.97km)
# step: Sochi -> Novorossiysk (200.16km)
# step: Novorossiysk -> Belgorod (660.82km)
# step: Belgorod -> Kaluga (437.86km)
# step: Kaluga -> Kirov (936.75km)
# step: Kirov -> Syktyvkar (347.95km)
# step: Syktyvkar -> Arkhangelsk (610.18km)
# step: Arkhangelsk -> Severodvinsk (33.55km)
# step: Severodvinsk -> Murmansk (572.02km)
# step: Murmansk -> Kaliningrad (1712.77km)
# step: Kaliningrad -> Nefteyugansk (3086.69km)
# step: Nefteyugansk -> Surgut (43.14km)
# step: Surgut -> Nizhnevartovsk (173.64km)
# step: Nizhnevartovsk -> Noyabrsk (254.53km)
# step: Noyabrsk -> Novyy Urengoy (328.30km)
# step: Novyy Urengoy -> Norilsk (612.52km)
# step: Norilsk -> Bratsk (1599.47km)
# step: Bratsk -> Angarsk (439.00km)
# step: Angarsk -> Irkutsk (34.88km)
# step: Irkutsk -> Ulan‐Ude (238.28km)
# step: Ulan‐Ude -> Chita (402.25km)
# step: Chita -> Blagoveshchensk (1002.31km)
# step: Blagoveshchensk -> Khabarovsk (588.32km)
# step: Khabarovsk -> Komsomolsk‐na‐Amure (274.21km)
# step: Komsomolsk‐na‐Amure -> Yuzhno‐Sakhalinsk (582.17km)
# step: Yuzhno‐Sakhalinsk -> Nakhodka (901.85km)
# step: Nakhodka -> Artyom (82.51km)
# step: Artyom -> Vladivostok (34.21km)
# step: Vladivostok -> Ussuriysk (74.97km)
# step: Ussuriysk -> Yakutsk (2034.16km)
# step: Yakutsk -> Magadan (1173.79km)
# step: Magadan -> Petropavlovsk‐Kamchatskiy (875.16km)
# step: Petropavlovsk‐Kamchatskiy -> Kyzyl (4230.63km)
# step: Kyzyl -> Abakan (299.57km)
# Italy
# step: Ancona -> Rimini (90.60km)
# step: Rimini -> Forlì (46.72km)
# step: Forlì -> Ravenna (26.46km)
# step: Ravenna -> Ferrara (66.67km)
# step: Ferrara -> Bologna (43.43km)
# step: Bologna -> Modena (37.29km)
# step: Modena -> Reggio nell'Emilia (23.94km)
# step: Reggio nell'Emilia -> Parma (26.94km)
# step: Parma -> Piacenza (57.65km)
# step: Piacenza -> Milan (60.65km)
# step: Milan -> Monza (14.51km)
# step: Monza -> Bergamo (33.92km)
# step: Bergamo -> Brescia (46.02km)
# step: Brescia -> Verona (61.42km)
# step: Verona -> Vicenza (44.70km)
# step: Vicenza -> Padua (30.13km)
# step: Padua -> Venice (36.07km)
# step: Venice -> Trieste (115.09km)
# step: Trieste -> Bolzano (209.68km)
# step: Bolzano -> Trento (49.94km)
# step: Trento -> Novara (206.69km)
# step: Novara -> Turin (84.46km)
# step: Turin -> Genoa (123.19km)
# step: Genoa -> Leghorn (146.37km)
# step: Leghorn -> Prato (74.02km)
# step: Prato -> Florence (17.17km)
# step: Florence -> Perugia (119.19km)
# step: Perugia -> Terni (63.64km)
# step: Terni -> Rome (76.54km)
# step: Rome -> Latina (56.84km)
# step: Latina -> Giugliano in Campania (124.45km)
# step: Giugliano in Campania -> Naples (11.15km)
# step: Naples -> Salerno (46.25km)
# step: Salerno -> Foggia (109.52km)
# step: Foggia -> Andria (67.42km)
# step: Andria -> Bari (50.18km)
# step: Bari -> Taranto (77.63km)
# step: Taranto -> Messina (293.02km)
# step: Messina -> Reggio di Calabria (12.48km)
# step: Reggio di Calabria -> Catania (84.28km)
# step: Catania -> Syracuse (51.23km)
# step: Syracuse -> Palermo (206.47km)
# step: Palermo -> Cagliari (390.28km)
# step: Cagliari -> Sassari (173.89km)
# step: Sassari -> Pescara (508.61km)
# step: Pescara -> Ancona (139.24km)
# Vanuatu
# step: Isangel -> Vila (223.00km)
# step: Vila -> Lakatoro (206.74km)
# step: Lakatoro -> Norsup (2.46km)
# step: Norsup -> Luganville (67.09km)
# step: Luganville -> Port Olry (52.02km)
# step: Port Olry -> Longana (105.77km)
# step: Longana -> Sola (165.49km)
# step: Sola -> Isangel (652.96km)
# INFO:root:China result: Found a path of 726 steps, total length 63962.92km
# China
# step: Acheng -> Harbin (33.60km)
# step: Harbin -> Shuangcheng (53.02km)
# step: Shuangcheng -> Yushu (61.85km)
# step: Yushu -> Wuchang (47.68km)
# step: Wuchang -> Shulan (59.07km)
# step: Shulan -> Jishu (17.91km)
# step: Jishu -> Jilin city (50.81km)
# step: Jilin city -> Jiutai (65.06km)
# step: Jiutai -> Dehui (43.68km)
# step: Dehui -> Changchun (78.49km)
# step: Changchun -> Gongzhuling (59.12km)
# step: Gongzhuling -> Siping (54.24km)
# step: Siping -> Liaoyuan (71.76km)
# step: Liaoyuan -> Meihekou (60.38km)
# step: Meihekou -> Panshi (55.16km)
# step: Panshi -> Huadian (56.40km)
# step: Huadian -> Jiaohe (96.49km)
# step: Jiaohe -> Dunhua (82.15km)
# step: Dunhua -> Helong (110.22km)
# step: Helong -> Longjing (42.88km)
# step: Longjing -> Yanji (14.70km)
# step: Yanji -> Tumen (26.45km)
# step: Tumen -> Huichun (46.09km)
# step: Huichun -> Ningan (179.31km)
# step: Ningan -> Hailin (26.54km)
# step: Hailin -> Mudanjiang (18.30km)
# step: Mudanjiang -> Muleng (81.67km)
# step: Muleng -> Hengshan (43.08km)
# step: Hengshan -> Jixi (12.77km)
# step: Jixi -> Didao (8.52km)
# step: Didao -> Qitaihe (52.26km)
# step: Qitaihe -> Mishan (84.93km)
# step: Mishan -> Hulin (85.55km)
# step: Hulin -> Baoshan (148.92km)
# step: Baoshan -> Shuangyashan (11.53km)
# step: Shuangyashan -> Jiamusi (78.45km)
# step: Jiamusi -> Hegang (63.39km)
# step: Hegang -> Nancha (88.49km)
# step: Nancha -> Yichun (72.65km)
# step: Yichun -> Tieli (108.21km)
# step: Tieli -> Suihua (89.11km)
# step: Suihua -> Hailun (91.24km)
# step: Hailun -> Beian (94.46km)
# step: Beian -> Wudalianchi (62.24km)
# step: Wudalianchi -> Nehe (99.17km)
# step: Nehe -> Qiqihar (142.80km)
# step: Qiqihar -> Hulan Ergi (33.36km)
# step: Hulan Ergi -> Longjiang (35.60km)
# step: Longjiang -> Zalantun (81.11km)
# step: Zalantun -> Yakeshi (204.36km)
# step: Yakeshi -> Hailar (74.46km)
# step: Hailar -> Hulunbeir (3.42km)
# step: Hulunbeir -> Zhalainuoer (147.71km)
# step: Zhalainuoer -> Manzhouli (24.90km)
# step: Manzhouli -> Genhe (320.38km)
# step: Genhe -> Jiagedagi (186.53km)
# step: Jiagedagi -> Heihe (239.79km)
# step: Heihe -> Ranghulu (446.36km)
# step: Ranghulu -> Saertu (13.95km)
# step: Saertu -> Longfeng (8.21km)
# step: Longfeng -> Honggang (20.45km)
# step: Honggang -> Anda (35.45km)
# step: Anda -> Zhaodong (62.75km)
# step: Zhaodong -> Zhaoyuan (94.24km)
# step: Zhaoyuan -> Songyuan (44.10km)
# step: Songyuan -> Qianguo (4.81km)
# step: Qianguo -> Qianan (63.65km)
# step: Qianan -> Taonan (104.56km)
# step: Taonan -> Baicheng (32.38km)
# step: Baicheng -> Ulanhot (78.08km)
# step: Ulanhot -> Tongliao (279.51km)
# step: Tongliao -> Shuangliao (100.03km)
# step: Shuangliao -> Tiefa (118.79km)
# step: Tiefa -> Tieling (28.18km)
# step: Tieling -> Fushun (48.02km)
# step: Fushun -> Dongling (27.15km)
# step: Dongling -> Yuhong (4.99km)
# step: Yuhong -> Shenyang (4.71km)
# step: Shenyang -> Sujiatun (18.04km)
# step: Sujiatun -> Dengta (25.18km)
# step: Dengta -> Liaoyang (21.32km)
# step: Liaoyang -> Anshan (26.23km)
# step: Anshan -> Jiupu (5.55km)
# step: Jiupu -> Liaozhong (52.23km)
# step: Liaozhong -> Xinmin (54.94km)
# step: Xinmin -> Beining (95.71km)
# step: Beining -> Fuxin (47.93km)
# step: Fuxin -> Beipiao (77.32km)
# step: Beipiao -> Chaoyang (37.06km)
# step: Chaoyang -> Jinzhou (75.90km)
# step: Jinzhou -> Linghai (21.62km)
# step: Linghai -> Panjin (58.76km)
# step: Panjin -> Yingkou (59.86km)
# step: Yingkou -> Dashiqiao (18.90km)
# step: Dashiqiao -> Gaizhou (29.53km)
# step: Gaizhou -> Wafangdian (91.62km)
# step: Wafangdian -> Pulandian (24.67km)
# step: Pulandian -> Dalian (59.65km)
# step: Dalian -> Zhuanghe (142.37km)
# step: Zhuanghe -> Donggang (102.97km)
# step: Donggang -> Dandong (36.20km)
# step: Dandong -> Fengcheng (45.45km)
# step: Fengcheng -> Benxi (101.30km)
# step: Benxi -> Tonghua (187.63km)
# step: Tonghua -> Baishan (45.88km)
# step: Baishan -> Linjiang (42.84km)
# step: Linjiang -> Shangzhi (387.34km)
# step: Shangzhi -> Fujin (386.54km)
# step: Fujin -> Tongjiang (55.63km)
# step: Tongjiang -> Huludao (1207.56km)
# step: Huludao -> Xingcheng (13.96km)
# step: Xingcheng -> Qinhuangdao (121.57km)
# step: Qinhuangdao -> Linxi (105.04km)
# step: Linxi -> Tangshan (22.43km)
# step: Tangshan -> Hangu (55.87km)
# step: Hangu -> Tanggu (27.25km)
# step: Tanggu -> Gangdong (14.30km)
# step: Gangdong -> Tianjin (45.07km)
# step: Tianjin -> Langfang (62.33km)
# step: Langfang -> Huangcun (39.39km)
# step: Huangcun -> Beijing (22.18km)
# step: Beijing -> Tongzhou (20.79km)
# step: Tongzhou -> Yanjiao (15.33km)
# step: Yanjiao -> Sanhe (24.71km)
# step: Sanhe -> Shunyi (39.86km)
# step: Shunyi -> Changping (38.79km)
# step: Changping -> Mentougou (33.01km)
# step: Mentougou -> Fangshan (29.31km)
# step: Fangshan -> Zhuozhou (22.99km)
# step: Zhuozhou -> Gaobeidian (22.81km)
# step: Gaobeidian -> Bazhou (49.83km)
# step: Bazhou -> Renqiu (55.25km)
# step: Renqiu -> Hejian (27.87km)
# step: Hejian -> Botou (57.71km)
# step: Botou -> Cangzhou (39.44km)
# step: Cangzhou -> Huanghua (42.42km)
# step: Huanghua -> Leling (71.47km)
# step: Leling -> Binzhou (80.30km)
# step: Binzhou -> Dongying (48.34km)
# step: Dongying -> Hekou (5.62km)
# step: Hekou -> Shouguang (74.79km)
# step: Shouguang -> Qingzhou (29.10km)
# step: Qingzhou -> Yidu (2.04km)
# step: Yidu -> Zibo (39.23km)
# step: Zibo -> Zhoucun (18.83km)
# step: Zhoucun -> Zhangqiu (31.46km)
# step: Zhangqiu -> Boshan (44.53km)
# step: Boshan -> Laiwu (35.44km)
# step: Laiwu -> Xintai (34.49km)
# step: Xintai -> Taian (66.59km)
# step: Taian -> Jinan (53.25km)
# step: Jinan -> Liaocheng (95.99km)
# step: Liaocheng -> Linqing (53.34km)
# step: Linqing -> Nangong (64.34km)
# step: Nangong -> Jizhou (28.10km)
# step: Jizhou -> Hengshui (21.50km)
# step: Hengshui -> Shenzhou (33.22km)
# step: Shenzhou -> Xinji (34.58km)
# step: Xinji -> Gaocheng (33.50km)
# step: Gaocheng -> Luancheng (22.13km)
# step: Luancheng -> Shijiazhuang (24.07km)
# step: Shijiazhuang -> Luquan (14.80km)
# step: Luquan -> Xinle (47.41km)
# step: Xinle -> Dingzhou (27.75km)
# step: Dingzhou -> Anguo (31.16km)
# step: Anguo -> Baoding (52.29km)
# step: Baoding -> Dezhou (173.23km)
# step: Dezhou -> Xingtai (166.00km)
# step: Xingtai -> Shahe (17.48km)
# step: Shahe -> Handan (38.25km)
# step: Handan -> Linshui (28.93km)
# step: Linshui -> Wuan (27.76km)
# step: Wuan -> Anyang (70.28km)
# step: Anyang -> Hebi (18.59km)
# step: Hebi -> Linzhou (33.37km)
# step: Linzhou -> Huixian (62.42km)
# step: Huixian -> Xinxiang (16.75km)
# step: Xinxiang -> Weihui (20.63km)
# step: Weihui -> Kaifeng (70.25km)
# step: Kaifeng -> Zhengzhou (63.21km)
# step: Zhengzhou -> Xingyang (29.53km)
# step: Xingyang -> Xinmi (32.02km)
# step: Xinmi -> Xinzheng (29.62km)
# step: Xinzheng -> Yuzhou (8.28km)
# step: Yuzhou -> Changge (29.45km)
# step: Changge -> Xuchang (22.12km)
# step: Xuchang -> Luohe (53.57km)
# step: Luohe -> Wugang (55.85km)
# step: Wugang -> Pingdingshan (52.65km)
# step: Pingdingshan -> Ruzhou (64.55km)
# step: Ruzhou -> Dengfeng (38.72km)
# step: Dengfeng -> Gongyi (34.25km)
# step: Gongyi -> Xiaoyi (1.57km)
# step: Xiaoyi -> Yanshi (15.79km)
# step: Yanshi -> Mengzhou (20.34km)
# step: Mengzhou -> Qinyang (23.01km)
# step: Qinyang -> Jiyuan (31.92km)
# step: Jiyuan -> Jincheng (51.39km)
# step: Jincheng -> Gaoping (34.58km)
# step: Gaoping -> Changzhi (36.54km)
# step: Changzhi -> Jiaozuo (96.38km)
# step: Jiaozuo -> Yima (136.57km)
# step: Yima -> Sanmenxia (73.34km)
# step: Sanmenxia -> Yuncheng (22.51km)
# step: Yuncheng -> Yongji (51.48km)
# step: Yongji -> Lingbao (53.80km)
# step: Lingbao -> Shangluo (111.90km)
# step: Shangluo -> Weinan (80.64km)
# step: Weinan -> Xian (60.79km)
# step: Xian -> Xianyang (21.49km)
# step: Xianyang -> Xingping (20.80km)
# step: Xingping -> Tongchuan (100.96km)
# step: Tongchuan -> Hancheng (130.45km)
# step: Hancheng -> Houma (72.66km)
# step: Houma -> Linfen (58.22km)
# step: Linfen -> Fenyang (0.48km)
# step: Fenyang -> Lüliang (0.00km)
# step: Lüliang -> Huozhou (58.32km)
# step: Huozhou -> Jiexiu (53.25km)
# step: Jiexiu -> Gujiao (97.44km)
# step: Gujiao -> Taiyuan (44.76km)
# step: Taiyuan -> Jinzhong (26.27km)
# step: Jinzhong -> Yuci (0.47km)
# step: Yuci -> Yangquan (76.95km)
# step: Yangquan -> Xinzhou (95.19km)
# step: Xinzhou -> Yuanping County (34.39km)
# step: Yuanping County -> Shuozhou (70.83km)
# step: Shuozhou -> Datong (113.95km)
# step: Datong -> Fengzhen (42.93km)
# step: Fengzhen -> Ulanchabu (61.08km)
# step: Ulanchabu -> Jining (5.75km)
# step: Jining -> Hohhot (124.54km)
# step: Hohhot -> Baotou (136.56km)
# step: Baotou -> Erdos (90.87km)
# step: Erdos -> Yulin (169.75km)
# step: Yulin -> Yanan (188.27km)
# step: Yanan -> Pingliang (277.96km)
# step: Pingliang -> Guyuan (66.54km)
# step: Guyuan -> Dingxi (154.54km)
# step: Dingxi -> Lanzhou (100.13km)
# step: Lanzhou -> Linxia (64.71km)
# step: Linxia -> Baiyin (135.55km)
# step: Baiyin -> Zhongwei (139.40km)
# step: Zhongwei -> Qingtongxia (82.75km)
# step: Qingtongxia -> Wuzhong (22.37km)
# step: Wuzhong -> Lingwu (16.13km)
# step: Lingwu -> Yinchuan (41.09km)
# step: Yinchuan -> Dawukou (61.15km)
# step: Dawukou -> Shizuishan (41.71km)
# step: Shizuishan -> Hainan (9.84km)
# step: Hainan -> Wuda (24.87km)
# step: Wuda -> Wuhai (16.72km)
# step: Wuhai -> Linhe (148.31km)
# step: Linhe -> Bayannaoer (420.81km)
# step: Bayannaoer -> Wuwei (103.61km)
# step: Wuwei -> Jinchang (78.25km)
# step: Jinchang -> Zhangye (158.10km)
# step: Zhangye -> Jiuquan (190.41km)
# step: Jiuquan -> Jiayuguan (19.60km)
# step: Jiayuguan -> Yumen (48.81km)
# step: Yumen -> Dunhuang (264.02km)
# step: Dunhuang -> Hami (311.36km)
# step: Hami -> Turpan (349.08km)
# step: Turpan -> Ürümqi (158.45km)
# step: Ürümqi -> Miquan (20.88km)
# step: Miquan -> Fukang (26.32km)
# step: Fukang -> Changji (50.72km)
# step: Changji -> Shihezi (107.77km)
# step: Shihezi -> Kuytun (92.19km)
# step: Kuytun -> Usu (55.00km)
# step: Usu -> Karamay (141.42km)
# step: Karamay -> Tacheng (193.23km)
# step: Tacheng -> Bole County (217.10km)
# step: Bole County -> Yining (125.45km)
# step: Yining -> Tumushuke (303.42km)
# step: Tumushuke -> Aksu (33.81km)
# step: Aksu -> Alaer (110.78km)
# step: Alaer -> Hotan (394.32km)
# step: Hotan -> Shache (284.41km)
# step: Shache -> Kashi (161.74km)
# step: Kashi -> Atushi (28.91km)
# step: Atushi -> Korla (873.94km)
# step: Korla -> Altay (696.77km)
# step: Altay -> Golmud (1384.94km)
# step: Golmud -> Xining (617.12km)
# step: Xining -> Tianshui (424.25km)
# step: Tianshui -> Longnan (151.40km)
# step: Longnan -> Guangyuan (139.73km)
# step: Guangyuan -> Langzhong (94.61km)
# step: Langzhong -> Bazhong (80.98km)
# step: Bazhong -> Daxian (98.59km)
# step: Daxian -> Dazhou (6.21km)
# step: Dazhou -> Wanyuan (95.85km)
# step: Wanyuan -> Ankang (125.71km)
# step: Ankang -> Shiyan (165.62km)
# step: Shiyan -> Danjiangkou (67.65km)
# step: Danjiangkou -> Laohekou (23.26km)
# step: Laohekou -> Dengzhou (54.01km)
# step: Dengzhou -> Nanyang (52.09km)
# step: Nanyang -> Zaoyang (98.67km)
# step: Zaoyang -> Xiangfan (59.80km)
# step: Xiangfan -> Yicheng (36.20km)
# step: Yicheng -> Yingzhong (67.59km)
# step: Yingzhong -> Zhongxiang (0.49km)
# step: Zhongxiang -> Jingmen (40.47km)
# step: Jingmen -> Dangyang (44.64km)
# step: Dangyang -> Zhijiang (45.55km)
# step: Zhijiang -> Zhicheng (28.62km)
# step: Zhicheng -> Yichang (48.71km)
# step: Yichang -> Jingzhou (94.69km)
# step: Jingzhou -> Songzi (4.61km)
# step: Songzi -> Shashi (1.69km)
# step: Shashi -> Buhe (4.54km)
# step: Buhe -> Shishou (62.89km)
# step: Shishou -> Rongcheng (47.48km)
# step: Rongcheng -> Yueyang (53.22km)
# step: Yueyang -> Linxiang (36.89km)
# step: Linxiang -> Honghu (39.16km)
# step: Honghu -> Chibi (43.13km)
# step: Chibi -> Xianning (35.85km)
# step: Xianning -> Daye County (77.59km)
# step: Daye County -> Huangshi (17.41km)
# step: Huangshi -> Ezhou (32.75km)
# step: Ezhou -> Huangzhou (6.25km)
# step: Huangzhou -> Wuhan (58.44km)
# step: Wuhan -> Hanchuan (42.71km)
# step: Hanchuan -> Xiaogan (31.76km)
# step: Xiaogan -> Yingcheng (31.89km)
# step: Yingcheng -> Anlu (38.61km)
# step: Anlu -> Guangshui (49.90km)
# step: Guangshui -> Xinyang (56.94km)
# step: Xinyang -> Suizhou (81.72km)
# step: Suizhou -> Tianmen (117.97km)
# step: Tianmen -> Qianjiang (36.35km)
# step: Qianjiang -> Xiantao (54.10km)
# step: Xiantao -> Macheng (175.33km)
# step: Macheng -> Luan (151.60km)
# step: Luan -> Hefei (76.57km)
# step: Hefei -> Feidong (16.48km)
# step: Feidong -> Chaohu (49.94km)
# step: Chaohu -> Wuhu (55.01km)
# step: Wuhu -> Maanshan (43.41km)
# step: Maanshan -> Nanjing (45.44km)
# step: Nanjing -> Jurong (37.28km)
# step: Jurong -> Yizheng (37.63km)
# step: Yizheng -> Zhenjiang (22.37km)
# step: Zhenjiang -> Yangzhou (19.96km)
# step: Yangzhou -> Jiangdu (13.58km)
# step: Jiangdu -> Taizhou (32.68km)
# step: Taizhou -> Jiangyan (22.02km)
# step: Jiangyan -> Taixing (39.94km)
# step: Taixing -> Jingjiang (31.10km)
# step: Jingjiang -> Jiangyin (15.38km)
# step: Jiangyin -> Zhangjiagang (28.05km)
# step: Zhangjiagang -> Nantong (29.79km)
# step: Nantong -> Changshu (41.84km)
# step: Changshu -> Kunshan (36.00km)
# step: Kunshan -> Taicang (15.26km)
# step: Taicang -> Shanghai (43.18km)
# step: Shanghai -> Pinghu (73.00km)
# step: Pinghu -> Jiaxing (26.69km)
# step: Jiaxing -> Tongxiang (25.70km)
# step: Tongxiang -> Haining (18.16km)
# step: Haining -> Wujiang (56.85km)
# step: Wujiang -> Huzhou (53.68km)
# step: Huzhou -> Deqing (35.53km)
# step: Deqing -> Hangzhou (34.36km)
# step: Hangzhou -> Fuyang (30.23km)
# step: Fuyang -> Lin'an (29.63km)
# step: Lin'an -> Zhuji (77.24km)
# step: Zhuji -> Yiwu (23.72km)
# step: Yiwu -> Dongyang (31.77km)
# step: Dongyang -> Yongkang (44.47km)
# step: Yongkang -> Jinhua (44.21km)
# step: Jinhua -> Lanxi (20.34km)
# step: Lanxi -> Jiande (32.98km)
# step: Jiande -> Quzhou (73.34km)
# step: Quzhou -> Jiangshan (35.26km)
# step: Jiangshan -> Shangrao (70.53km)
# step: Shangrao -> Dexing (65.19km)
# step: Dexing -> Leping (43.46km)
# step: Leping -> Jingdezhen (33.93km)
# step: Jingdezhen -> Hejin (56.22km)
# step: Hejin -> Nanchang (86.36km)
# step: Nanchang -> Gaoan (57.64km)
# step: Gaoan -> Zhangshu (42.06km)
# step: Zhangshu -> Xinyu (66.70km)
# step: Xinyu -> Jian (74.56km)
# step: Jian -> Jinggangshan (107.38km)
# step: Jinggangshan -> Zixing (99.21km)
# step: Zixing -> Chenzhou (41.42km)
# step: Chenzhou -> Leiyang (71.27km)
# step: Leiyang -> Changning (42.60km)
# step: Changning -> Qidong (59.18km)
# step: Qidong -> Hengyang (51.17km)
# step: Hengyang -> Xiangxiang (94.71km)
# step: Xiangxiang -> Shaoshan (19.25km)
# step: Shaoshan -> Xiangtan (41.89km)
# step: Xiangtan -> Zhuzhou (24.73km)
# step: Zhuzhou -> Liling (37.92km)
# step: Liling -> Xiangdong (24.89km)
# step: Xiangdong -> Pingxiang (11.08km)
# step: Pingxiang -> Liuyang (61.91km)
# step: Liuyang -> Changsha (64.65km)
# step: Changsha -> Miluo (68.24km)
# step: Miluo -> Yuanjiang (68.15km)
# step: Yuanjiang -> Yiyang (25.96km)
# step: Yiyang -> Changde (79.35km)
# step: Changde -> Jinshi (68.52km)
# step: Jinshi -> Zhangjiajie (143.64km)
# step: Zhangjiajie -> Jishou (116.99km)
# step: Jishou -> Huaihua (86.96km)
# step: Huaihua -> Hongjiang (49.01km)
# step: Hongjiang -> Tongren (105.28km)
# step: Tongren -> Kaili (171.01km)
# step: Kaili -> Fuquan (44.96km)
# step: Fuquan -> Duyun (45.94km)
# step: Duyun -> Guiyang (86.88km)
# step: Guiyang -> Qingzhen (25.46km)
# step: Qingzhen -> Anshun (63.02km)
# step: Anshun -> Liupanshui (112.83km)
# step: Liupanshui -> Xuanwei (84.81km)
# step: Xuanwei -> Qujing (88.80km)
# step: Qujing -> Jinma (113.70km)
# step: Jinma -> Kunming (5.17km)
# step: Kunming -> Majie (5.05km)
# step: Majie -> Anning (22.60km)
# step: Anning -> Haikou (13.15km)
# step: Haikou -> Longquan (48.84km)
# step: Longquan -> Yuxi (53.34km)
# step: Yuxi -> Zhoucheng (2.02km)
# step: Zhoucheng -> Kaiyuan (100.89km)
# step: Kaiyuan -> Gejiu (37.95km)
# step: Gejiu -> Simao (232.06km)
# step: Simao -> Jinghong (89.81km)
# step: Jinghong -> Lincang (223.45km)
# step: Lincang -> Luxi (163.28km)
# step: Luxi -> Ruili (90.10km)
# step: Ruili -> Dali (298.11km)
# step: Dali -> Chuxiong (158.08km)
# step: Chuxiong -> Lucheng (1.18km)
# step: Lucheng -> Panzhihua (172.21km)
# step: Panzhihua -> Xichang (156.59km)
# step: Xichang -> Zhaotong (153.31km)
# step: Zhaotong -> Wufeng (112.57km)
# step: Wufeng -> Bijie (44.91km)
# step: Bijie -> Renhuai (124.73km)
# step: Renhuai -> Zunyi (50.81km)
# step: Zunyi -> Chishui (155.42km)
# step: Chishui -> Luzhou (44.67km)
# step: Luzhou -> Yongchuan (73.96km)
# step: Yongchuan -> Daan (12.22km)
# step: Daan -> Jiangjin (25.77km)
# step: Jiangjin -> Chongqing (44.26km)
# step: Chongqing -> Beibei (31.85km)
# step: Beibei -> Hechuan (22.32km)
# step: Hechuan -> Guang'an (66.31km)
# step: Guang'an -> Huaying (19.30km)
# step: Huaying -> Nanchong (77.66km)
# step: Nanchong -> Suining (63.84km)
# step: Suining -> Ziyang (95.88km)
# step: Ziyang -> Neijiang (73.64km)
# step: Neijiang -> Zigong (32.92km)
# step: Zigong -> Yibin (72.76km)
# step: Yibin -> Leshan (119.92km)
# step: Leshan -> Emeishan (25.23km)
# step: Emeishan -> Yaan (57.23km)
# step: Yaan -> Qionglai (61.07km)
# step: Qionglai -> Chongzhou (30.90km)
# step: Chongzhou -> Dujiangyan (34.18km)
# step: Dujiangyan -> Pengzhou (42.43km)
# step: Pengzhou -> Guanghan (30.26km)
# step: Guanghan -> Deyang (21.12km)
# step: Deyang -> Mianzhu (29.52km)
# step: Mianzhu -> Shifang (0.00km)
# step: Shifang -> Mianyang (56.29km)
# step: Mianyang -> Jiangyou (33.28km)
# step: Jiangyou -> Chengdu (138.55km)
# step: Chengdu -> Meishan (71.85km)
# step: Meishan -> Fuling (341.64km)
# step: Fuling -> Nanchuan (139.30km)
# step: Nanchuan -> Lichuan (87.67km)
# step: Lichuan -> Enshi (52.96km)
# step: Enshi -> Wanxian (118.84km)
# step: Wanxian -> Hanzhong (287.01km)
# step: Hanzhong -> Baoji (139.44km)
# step: Baoji -> Zhumadian (637.68km)
# step: Zhumadian -> Zhoukou (91.87km)
# step: Zhoukou -> Jieshou (79.70km)
# step: Jieshou -> Bozhou (78.60km)
# step: Bozhou -> Yongcheng (64.17km)
# step: Yongcheng -> Huaibei (27.82km)
# step: Huaibei -> Suzhou (43.62km)
# step: Suzhou -> Xuzhou (74.35km)
# step: Xuzhou -> Xiazhen (61.45km)
# step: Xiazhen -> Tengzhou (30.30km)
# step: Tengzhou -> Zoucheng (38.23km)
# step: Zoucheng -> Zouxian (2.66km)
# step: Zouxian -> Yanzhou (18.97km)
# step: Yanzhou -> Qufu (14.68km)
# step: Qufu -> Yucheng (87.63km)
# step: Yucheng -> Shangqiu (92.74km)
# step: Shangqiu -> Heze (89.35km)
# step: Heze -> Xiangcheng (41.54km)
# step: Xiangcheng -> Puyang (37.86km)
# step: Puyang -> Zaozhuang (252.54km)
# step: Zaozhuang -> Feicheng (55.44km)
# step: Feicheng -> Linyi (40.53km)
# step: Linyi -> Heilin (52.19km)
# step: Heilin -> Lianyungang (51.61km)
# step: Lianyungang -> Xinyi (78.87km)
# step: Xinyi -> Pizhou (31.88km)
# step: Pizhou -> Suqian (51.90km)
# step: Suqian -> Huaiyin (79.51km)
# step: Huaiyin -> Huaian (13.07km)
# step: Huaian -> Tianchang (63.51km)
# step: Tianchang -> Xinghua (31.62km)
# step: Xinghua -> Gaoyou (42.14km)
# step: Gaoyou -> Dongtai (81.84km)
# step: Dongtai -> Dafeng (40.67km)
# step: Dafeng -> Yancheng (35.75km)
# step: Yancheng -> Rugao (118.67km)
# step: Rugao -> Changzhou (86.45km)
# step: Changzhou -> Wuxi (38.35km)
# step: Wuxi -> Jintan (72.86km)
# step: Jintan -> Liyang (30.68km)
# step: Liyang -> Yixing (47.55km)
# step: Yixing -> Ningguo (53.86km)
# step: Ningguo -> Xuanzhou (41.97km)
# step: Xuanzhou -> Tongling (91.74km)
# step: Tongling -> Chizhou (43.94km)
# step: Chizhou -> Anqing (44.47km)
# step: Anqing -> Tongcheng (50.06km)
# step: Tongcheng -> Lujiang (46.95km)
# step: Lujiang -> Chuzhou (152.75km)
# step: Chuzhou -> Mingguang (60.17km)
# step: Mingguang -> Bengbu (64.03km)
# step: Bengbu -> Huainan (48.31km)
# step: Huainan -> Yunyang (252.79km)
# step: Yunyang -> Danyang (0.63km)
# step: Danyang -> Shaoxing (241.55km)
# step: Shaoxing -> Shangyu (28.68km)
# step: Shangyu -> Yuyao (27.58km)
# step: Yuyao -> Cixi (15.22km)
# step: Cixi -> Ningbo (44.08km)
# step: Ningbo -> Fenghua (28.57km)
# step: Fenghua -> Shengzhou (58.37km)
# step: Shengzhou -> Linhai (88.94km)
# step: Linhai -> Huangyan (25.11km)
# step: Huangyan -> Luqiao (14.89km)
# step: Luqiao -> Jiaojiang (13.03km)
# step: Jiaojiang -> Wenling (35.72km)
# step: Wenling -> Yueqing (47.25km)
# step: Yueqing -> Wenzhou (32.43km)
# step: Wenzhou -> Ruian (19.74km)
# step: Ruian -> Fuding (81.60km)
# step: Fuding -> Fuan (56.69km)
# step: Fuan -> Ningde (49.39km)
# step: Ningde -> Changle (82.94km)
# step: Changle -> Fuqing (28.34km)
# step: Fuqing -> Nantongkuang (27.75km)
# step: Nantongkuang -> Putian (61.08km)
# step: Putian -> Bantou (34.85km)
# step: Bantou -> Quanzhou (53.03km)
# step: Quanzhou -> Jinjiang (8.92km)
# step: Jinjiang -> Qingyang (0.00km)
# step: Qingyang -> Shishi (11.92km)
# step: Shishi -> Nan'an (36.33km)
# step: Nan'an -> Xiamen (64.51km)
# step: Xiamen -> Longhai (32.71km)
# step: Longhai -> Zhangzhou (17.13km)
# step: Zhangzhou -> Zhangping (88.34km)
# step: Zhangping -> Longyan (40.61km)
# step: Longyan -> Yongan (94.28km)
# step: Yongan -> Sanming (36.01km)
# step: Sanming -> Nanping (73.67km)
# step: Nanping -> Jian'ou (47.30km)
# step: Jian'ou -> Jianyang (38.63km)
# step: Jianyang -> Wuyishan (48.94km)
# step: Wuyishan -> Shaowu (73.82km)
# step: Shaowu -> Guixi (112.99km)
# step: Guixi -> Yingtai (17.95km)
# step: Yingtai -> Linchuan (70.96km)
# step: Linchuan -> Fuzhou (2.10km)
# step: Fuzhou -> Jiujiang (196.93km)
# step: Jiujiang -> Ruichang (31.37km)
# step: Ruichang -> Wuxue (21.77km)
# step: Wuxue -> Huangshan (266.32km)
# step: Huangshan -> Lishui (209.68km)
# step: Lishui -> Zhoushan (280.09km)
# step: Zhoushan -> Rizhao (656.69km)
# step: Rizhao -> Zhucheng (62.46km)
# step: Zhucheng -> Anqiu (51.73km)
# step: Anqiu -> Weifang (33.17km)
# step: Weifang -> Changyi (29.12km)
# step: Changyi -> Pingdu (50.11km)
# step: Pingdu -> Laizhou (42.17km)
# step: Laizhou -> Zhaocheng (46.72km)
# step: Zhaocheng -> Longkou (32.95km)
# step: Longkou -> Penglai (40.08km)
# step: Penglai -> Qixia (58.11km)
# step: Qixia -> Laiyang (38.68km)
# step: Laiyang -> Laixi (18.76km)
# step: Laixi -> Jimo (54.40km)
# step: Jimo -> Qingdao (36.63km)
# step: Qingdao -> Jiaozhou (37.74km)
# step: Jiaozhou -> Gaomi (25.04km)
# step: Gaomi -> Jiaonan (59.66km)
# step: Jiaonan -> Haiyang (147.38km)
# step: Haiyang -> Rushan (32.50km)
# step: Rushan -> Wendeng (59.18km)
# step: Wendeng -> Weihai (33.59km)
# step: Weihai -> Yantai (61.97km)
# step: Yantai -> Zunhua (418.95km)
# step: Zunhua -> Chengde (86.30km)
# step: Chengde -> Lingyuan (126.80km)
# step: Lingyuan -> Chifeng (119.05km)
# step: Chifeng -> Xilinhot (298.76km)
# step: Xilinhot -> Zhangjiakou (359.34km)
# step: Zhangjiakou -> Loudi (1475.90km)
# step: Loudi -> Lianyuan (33.10km)
# step: Lianyuan -> Lengshuijiang (23.78km)
# step: Lengshuijiang -> Shaoyang (78.43km)
# step: Shaoyang -> Yongzhou (94.16km)
# step: Yongzhou -> Guilin (169.15km)
# step: Guilin -> Liuzhou (152.05km)
# step: Liuzhou -> Heshan (63.57km)
# step: Heshan -> Laibin (40.94km)
# step: Laibin -> Guigang (75.34km)
# step: Guigang -> Guiping (57.96km)
# step: Guiping -> Beiliu (106.54km)
# step: Beiliu -> Cenxi (71.65km)
# step: Cenxi -> Luoding (59.07km)
# step: Luoding -> Yunfu (51.30km)
# step: Yunfu -> Gaoyao (44.09km)
# step: Gaoyao -> Zhaoqing (2.13km)
# step: Zhaoqing -> Sihui (40.92km)
# step: Sihui -> Xinan (29.06km)
# step: Xinan -> Foshan (28.21km)
# step: Foshan -> Guangzhou (16.64km)
# step: Guangzhou -> Huangpu (17.55km)
# step: Huangpu -> Shiqiao (18.76km)
# step: Shiqiao -> Daliang (15.81km)
# step: Daliang -> Xiaolan (7.32km)
# step: Xiaolan -> Zhongshan (28.60km)
# step: Zhongshan -> Jiangmen (28.32km)
# step: Jiangmen -> Shaping (24.39km)
# step: Shaping -> Kaiping (52.61km)
# step: Kaiping -> Taicheng (15.01km)
# step: Taicheng -> Taishan (1.76km)
# step: Taishan -> Enping (50.38km)
# step: Enping -> Yangjiang (50.23km)
# step: Yangjiang -> Yangchun (40.42km)
# step: Yangchun -> Maoming (99.24km)
# step: Maoming -> Gaozhou (3.29km)
# step: Gaozhou -> Huazhou (38.46km)
# step: Huazhou -> Wuchuan (25.92km)
# step: Wuchuan -> Zhanjiang (47.32km)
# step: Zhanjiang -> Dongli (39.87km)
# step: Dongli -> Leizhou (29.35km)
# step: Leizhou -> Lianjiang (93.64km)
# step: Lianjiang -> Beihai (126.26km)
# step: Beihai -> Qinzhou (71.94km)
# step: Qinzhou -> Fangchenggang (50.96km)
# step: Fangchenggang -> Dongxing (34.49km)
# step: Dongxing -> Chongzuo (114.72km)
# step: Chongzuo -> Nanning (107.71km)
# step: Nanning -> Yizhou (184.40km)
# step: Yizhou -> Hechi (56.39km)
# step: Hechi -> Jinchengjiang (25.82km)
# step: Jinchengjiang -> Baise (151.73km)
# step: Baise -> Xingyi (219.09km)
# step: Xingyi -> Wuzhou (676.64km)
# step: Wuzhou -> Hezhou (106.27km)
# step: Hezhou -> Lianzhou (93.17km)
# step: Lianzhou -> Lecheng (106.01km)
# step: Lecheng -> Shaoguan (44.25km)
# step: Shaoguan -> Maba (13.29km)
# step: Maba -> Yingde (59.22km)
# step: Yingde -> Conghua (62.70km)
# step: Conghua -> Zengcheng (43.29km)
# step: Zengcheng -> Shilong (19.72km)
# step: Shilong -> Dongguan (12.21km)
# step: Dongguan -> Humen (22.23km)
# step: Humen -> Shenzhen (56.76km)
# step: Shenzhen -> Danshui (46.21km)
# step: Danshui -> Pingshan (30.86km)
# step: Pingshan -> Huizhou (30.38km)
# step: Huizhou -> Luoyang (15.82km)
# step: Luoyang -> Heyuan (74.77km)
# step: Heyuan -> Haicheng (106.46km)
# step: Haicheng -> Shanwei (22.24km)
# step: Shanwei -> Jieshi (48.46km)
# step: Jieshi -> Jiazi (24.52km)
# step: Jiazi -> Huicheng (29.50km)
# step: Huicheng -> Lufeng (15.62km)
# step: Lufeng -> Puning (15.32km)
# step: Puning -> Jieyang (34.16km)
# step: Jieyang -> Mianchang (18.68km)
# step: Mianchang -> Haimen (6.95km)
# step: Haimen -> Shantou (19.80km)
# step: Shantou -> Anbu (10.02km)
# step: Anbu -> Chenghai (9.26km)
# step: Chenghai -> Chaozhou (25.82km)
# step: Chaozhou -> Huanggang (36.74km)
# step: Huanggang -> Meizhou (114.89km)
# step: Meizhou -> Xingning (49.38km)
# step: Xingning -> Hepo (82.33km)
# step: Hepo -> Nanxiong (242.11km)
# step: Nanxiong -> Nankang (76.34km)
# step: Nankang -> Ganzhou (36.02km)
# step: Ganzhou -> Ruijin (108.52km)
# step: Ruijin -> Qingyuan (379.36km)
# step: Qingyuan -> Zhuhai (169.15km)
# step: Zhuhai -> Wenchang (416.45km)
# step: Wenchang -> Qionghai (50.91km)
# step: Qionghai -> Wanning (49.66km)
# step: Wanning -> Wuzhishan (91.35km)
# step: Wuzhishan -> Sanya (60.28km)
# step: Sanya -> Dongfang (130.16km)
# step: Dongfang -> Danzhou (107.62km)
# step: Danzhou -> Lingao (46.50km)
# step: Lingao -> Qiongshan (70.84km)
# step: Qiongshan -> Lasa (2215.54km)
# step: Lasa -> Xigaze (219.18km)
# step: Xigaze -> Acheng (3775.93km)
# INFO:root:US result: Found a path of 326 steps, total length 48050.03km
# US
# step: Abilene -> Wichita Falls (196.78km)
# step: Wichita Falls -> Denton (149.68km)
# step: Denton -> Lewisville (23.92km)
# step: Lewisville -> Carrollton (10.02km)
# step: Carrollton -> Plano (15.78km)
# step: Plano -> Allen (9.27km)
# step: Allen -> McKinney (10.45km)
# step: McKinney -> Frisco (15.17km)
# step: Frisco -> Richardson (22.38km)
# step: Richardson -> Garland (10.04km)
# step: Garland -> Mesquite (16.57km)
# step: Mesquite -> Dallas (16.56km)
# step: Dallas -> Irving (20.41km)
# step: Irving -> Grand Prairie (19.83km)
# step: Grand Prairie -> Fort Worth (32.28km)
# step: Fort Worth -> Waco (136.07km)
# step: Waco -> Killeen (74.58km)
# step: Killeen -> Round Rock (61.72km)
# step: Round Rock -> Austin (25.47km)
# step: Austin -> San Antonio (118.67km)
# step: San Antonio -> Corpus Christi (220.93km)
# step: Corpus Christi -> Edinburg (175.38km)
# step: Edinburg -> McAllen (13.47km)
# step: McAllen -> Brownsville (82.29km)
# step: Brownsville -> Laredo (263.79km)
# step: Laredo -> Sugar Land (440.43km)
# step: Sugar Land -> Pearland (30.03km)
# step: Pearland -> League City (21.98km)
# step: League City -> Houston (41.91km)
# step: Houston -> The Woodlands (44.91km)
# step: The Woodlands -> College Station (88.74km)
# step: College Station -> Tyler (213.35km)
# step: Tyler -> Shreveport (143.25km)
# step: Shreveport -> Beaumont (266.31km)
# step: Beaumont -> Lafayette (204.19km)
# step: Lafayette -> Baton Rouge (90.95km)
# step: Baton Rouge -> Metairie (104.05km)
# step: Metairie -> New Orleans (11.80km)
# step: New Orleans -> Mobile (203.56km)
# step: Mobile -> Montgomery (254.71km)
# step: Montgomery -> Columbus (132.33km)
# step: Columbus -> Macon (120.37km)
# step: Macon -> Atlanta (126.00km)
# step: Atlanta -> Sandy Springs (19.36km)
# step: Sandy Springs -> Athens (92.34km)
# step: Athens -> Augusta (136.61km)
# step: Augusta -> Savannah (174.04km)
# step: Savannah -> North Charleston (144.09km)
# step: North Charleston -> Charleston (14.85km)
# step: Charleston -> Wilmington (246.79km)
# step: Wilmington -> Fayetteville (139.67km)
# step: Fayetteville -> Cary (78.79km)
# step: Cary -> Raleigh (16.49km)
# step: Raleigh -> Durham (29.13km)
# step: Durham -> Greensboro (84.02km)
# step: Greensboro -> High Point (19.18km)
# step: High Point -> Winston‐Salem (27.65km)
# step: Winston‐Salem -> Concord (85.89km)
# step: Concord -> Charlotte (27.00km)
# step: Charlotte -> Roanoke (242.61km)
# step: Roanoke -> Alexandria (304.91km)
# step: Alexandria -> Arlington (6.85km)
# step: Arlington -> Washington (7.80km)
# step: Washington -> Columbia (35.70km)
# step: Columbia -> Baltimore (24.11km)
# step: Baltimore -> Philadelphia (149.23km)
# step: Philadelphia -> Allentown (71.23km)
# step: Allentown -> Edison (96.13km)
# step: Edison -> Elizabeth (22.34km)
# step: Elizabeth -> Newark (6.68km)
# step: Newark -> Jersey City (9.22km)
# step: Jersey City -> New York City (11.89km)
# step: New York City -> North Hempstead (26.86km)
# step: North Hempstead -> Oyster Bay (15.61km)
# step: Oyster Bay -> Stamford (35.77km)
# step: Stamford -> Yonkers (30.86km)
# step: Yonkers -> Paterson (25.12km)
# step: Paterson -> Ramapo (25.57km)
# step: Ramapo -> Bridgeport (76.48km)
# step: Bridgeport -> New Haven (26.51km)
# step: New Haven -> Waterbury (29.05km)
# step: Waterbury -> Hartford (37.38km)
# step: Hartford -> Worcester (91.57km)
# step: Worcester -> Lowell (57.27km)
# step: Lowell -> Cambridge (33.67km)
# step: Cambridge -> Boston (9.45km)
# step: Boston -> Quincy (7.94km)
# step: Quincy -> Brockton (19.85km)
# step: Brockton -> Providence (43.57km)
# step: Providence -> New Bedford (43.85km)
# step: New Bedford -> Lynn (90.39km)
# step: Lynn -> Manchester (69.02km)
# step: Manchester -> Syracuse (383.14km)
# step: Syracuse -> Amherst (213.04km)
# step: Amherst -> Buffalo (15.66km)
# step: Buffalo -> Cleveland (280.94km)
# step: Cleveland -> Akron (46.11km)
# step: Akron -> Pittsburgh (148.58km)
# step: Pittsburgh -> Toledo (332.16km)
# step: Toledo -> Ann Arbor (69.05km)
# step: Ann Arbor -> Dearborn (43.07km)
# step: Dearborn -> Detroit (11.89km)
# step: Detroit -> Warren (13.76km)
# step: Warren -> Sterling Heights (9.82km)
# step: Sterling Heights -> Lansing (125.95km)
# step: Lansing -> Grand Rapids (94.12km)
# step: Grand Rapids -> South Bend (151.36km)
# step: South Bend -> Fort Wayne (114.59km)
# step: Fort Wayne -> Dayton (166.14km)
# step: Dayton -> Cincinnati (75.54km)
# step: Cincinnati -> Lexington (122.15km)
# step: Lexington -> Louisville (105.20km)
# step: Louisville -> Evansville (166.76km)
# step: Evansville -> Clarksville (158.63km)
# step: Clarksville -> Nashville (66.67km)
# step: Nashville -> Murfreesboro (48.62km)
# step: Murfreesboro -> Huntsville (119.01km)
# step: Huntsville -> Chattanooga (122.12km)
# step: Chattanooga -> Knoxville (154.87km)
# step: Knoxville -> Birmingham (376.39km)
# step: Birmingham -> Memphis (340.86km)
# step: Memphis -> Little Rock (221.50km)
# step: Little Rock -> Jackson (333.39km)
# step: Jackson -> Tallahassee (603.11km)
# step: Tallahassee -> Gainesville (203.06km)
# step: Gainesville -> Jacksonville (98.42km)
# step: Jacksonville -> Orlando (201.82km)
# step: Orlando -> Lakeland (77.55km)
# step: Lakeland -> Brandon (36.50km)
# step: Brandon -> Riverview (12.29km)
# step: Riverview -> Tampa (23.56km)
# step: Tampa -> Saint Petersburg (28.18km)
# step: Saint Petersburg -> Clearwater (26.94km)
# step: Clearwater -> Spring Hill (60.05km)
# step: Spring Hill -> Palm Bay (191.24km)
# step: Palm Bay -> Port Saint Lucie (82.80km)
# step: Port Saint Lucie -> West Palm Beach (70.76km)
# step: West Palm Beach -> Pompano Beach (52.18km)
# step: Pompano Beach -> Fort Lauderdale (11.32km)
# step: Fort Lauderdale -> Hollywood (12.38km)
# step: Hollywood -> Miami Gardens (12.06km)
# step: Miami Gardens -> Miramar (5.12km)
# step: Miramar -> Pembroke Pines (7.46km)
# step: Pembroke Pines -> Davie (8.48km)
# step: Davie -> Coral Springs (21.39km)
# step: Coral Springs -> Hialeah (44.62km)
# step: Hialeah -> Miami (14.13km)
# step: Miami -> Lehigh Acres (170.43km)
# step: Lehigh Acres -> Cape Coral (35.86km)
# step: Cape Coral -> Chesapeake (1236.33km)
# step: Chesapeake -> Virginia Beach (27.18km)
# step: Virginia Beach -> Norfolk (25.33km)
# step: Norfolk -> Hampton (14.64km)
# step: Hampton -> Newport News (20.21km)
# step: Newport News -> Indianapolis (891.70km)
# step: Indianapolis -> Joliet (257.60km)
# step: Joliet -> Naperville (25.67km)
# step: Naperville -> Aurora (10.77km)
# step: Aurora -> Elgin (30.79km)
# step: Elgin -> Chicago (57.62km)
# step: Chicago -> Rockford (123.72km)
# step: Rockford -> Madison (96.40km)
# step: Madison -> Milwaukee (119.21km)
# step: Milwaukee -> Green Bay (161.17km)
# step: Green Bay -> Rochester (360.47km)
# step: Rochester -> Saint Paul (115.08km)
# step: Saint Paul -> Minneapolis (13.07km)
# step: Minneapolis -> Sioux Falls (318.71km)
# step: Sioux Falls -> Omaha (258.87km)
# step: Omaha -> Lincoln (73.78km)
# step: Lincoln -> Topeka (214.11km)
# step: Topeka -> Olathe (77.77km)
# step: Olathe -> Overland Park (11.14km)
# step: Overland Park -> Kansas City (26.30km)
# step: Kansas City -> Independence (34.03km)
# step: Independence -> Lee's Summit (18.66km)
# step: Lee's Summit -> Wichita (292.58km)
# step: Wichita -> Tulsa (215.76km)
# step: Tulsa -> Broken Arrow (14.91km)
# step: Broken Arrow -> Norman (166.95km)
# step: Norman -> Oklahoma City (29.42km)
# step: Oklahoma City -> Amarillo (393.42km)
# step: Amarillo -> Lubbock (181.04km)
# step: Lubbock -> Midland (171.68km)
# step: Midland -> Odessa (27.63km)
# step: Odessa -> El Paso (386.43km)
# step: El Paso -> Las Cruces (63.11km)
# step: Las Cruces -> Albuquerque (308.53km)
# step: Albuquerque -> Rio Rancho (20.46km)
# step: Rio Rancho -> Pueblo (380.30km)
# step: Pueblo -> Colorado Springs (67.21km)
# step: Colorado Springs -> Highlands Ranch (76.95km)
# step: Highlands Ranch -> Centennial (10.35km)
# step: Centennial -> Denver (19.04km)
# step: Denver -> Thornton (18.21km)
# step: Thornton -> Westminster (10.93km)
# step: Westminster -> Arvada (8.82km)
# step: Arvada -> Lakewood (12.34km)
# step: Lakewood -> Boulder (38.24km)
# step: Boulder -> Greeley (59.32km)
# step: Greeley -> Fort Collins (28.99km)
# step: Fort Collins -> Provo (559.50km)
# step: Provo -> West Jordan (49.84km)
# step: West Jordan -> West Valley City (9.62km)
# step: West Valley City -> Salt Lake City (12.08km)
# step: Salt Lake City -> Boise (473.45km)
# step: Boise -> Meridian (13.58km)
# step: Meridian -> Nampa (14.03km)
# step: Nampa -> Spokane Valley (456.56km)
# step: Spokane Valley -> Spokane (13.85km)
# step: Spokane -> Bellevue (356.24km)
# step: Bellevue -> Renton (13.80km)
# step: Renton -> Kent (10.26km)
# step: Kent -> Federal Way (12.39km)
# step: Federal Way -> Tacoma (11.28km)
# step: Tacoma -> Seattle (41.76km)
# step: Seattle -> Everett (44.57km)
# step: Everett -> Vancouver (264.99km)
# step: Vancouver -> Portland (11.90km)
# step: Portland -> Gresham (16.73km)
# step: Gresham -> Hillsboro (38.85km)
# step: Hillsboro -> Salem (66.18km)
# step: Salem -> Eugene (98.28km)
# step: Eugene -> Chico (489.74km)
# step: Chico -> Roseville (118.52km)
# step: Roseville -> Sacramento (26.38km)
# step: Sacramento -> Elk Grove (18.40km)
# step: Elk Grove -> Stockton (49.03km)
# step: Stockton -> Antioch (42.55km)
# step: Antioch -> Fairfield (37.57km)
# step: Fairfield -> Vacaville (12.75km)
# step: Vacaville -> Vallejo (37.83km)
# step: Vallejo -> Richmond (19.13km)
# step: Richmond -> Berkeley (10.95km)
# step: Berkeley -> Oakland (12.54km)
# step: Oakland -> San Francisco (18.69km)
# step: San Francisco -> Daly City (6.98km)
# step: Daly City -> San Mateo (20.72km)
# step: San Mateo -> Hayward (19.55km)
# step: Hayward -> Fremont (20.82km)
# step: Fremont -> Sunnyvale (14.22km)
# step: Sunnyvale -> Santa Clara (5.68km)
# step: Santa Clara -> San Jose (15.17km)
# step: San Jose -> Salinas (69.33km)
# step: Salinas -> Modesto (122.00km)
# step: Modesto -> Fresno (144.01km)
# step: Fresno -> Clovis (10.91km)
# step: Clovis -> Visalia (64.48km)
# step: Visalia -> Bakersfield (114.97km)
# step: Bakersfield -> Lancaster (103.78km)
# step: Lancaster -> Palmdale (12.87km)
# step: Palmdale -> Santa Clarita (41.81km)
# step: Santa Clarita -> Simi Valley (27.16km)
# step: Simi Valley -> Thousand Oaks (14.18km)
# step: Thousand Oaks -> Oxnard (30.47km)
# step: Oxnard -> San Buenaventura (Ventura) (8.65km)
# step: San Buenaventura (Ventura) -> Los Angeles (82.60km)
# step: Los Angeles -> Inglewood (9.34km)
# step: Inglewood -> Torrance (13.44km)
# step: Torrance -> Long Beach (17.47km)
# step: Long Beach -> Norwalk (12.73km)
# step: Norwalk -> Downey (5.59km)
# step: Downey -> East Los Angeles (10.92km)
# step: East Los Angeles -> El Monte (13.73km)
# step: El Monte -> West Covina (11.20km)
# step: West Covina -> Pomona (13.73km)
# step: Pomona -> Ontario (14.24km)
# step: Ontario -> Rancho Cucamonga (10.16km)
# step: Rancho Cucamonga -> Fontana (9.50km)
# step: Fontana -> Rialto (6.87km)
# step: Rialto -> San Bernardino (9.10km)
# step: San Bernardino -> Jurupa Valley (21.97km)
# step: Jurupa Valley -> Riverside (9.92km)
# step: Riverside -> Moreno Valley (17.41km)
# step: Moreno Valley -> Menifee (25.96km)
# step: Menifee -> Murrieta (13.10km)
# step: Murrieta -> Temecula (9.90km)
# step: Temecula -> Oceanside (35.10km)
# step: Oceanside -> Carlsbad (11.38km)
# step: Carlsbad -> Escondido (19.59km)
# step: Escondido -> San Diego (35.78km)
# step: San Diego -> El Cajon (16.41km)
# step: El Cajon -> Chula Vista (19.96km)
# step: Chula Vista -> Irvine (136.22km)
# step: Irvine -> Santa Ana (12.17km)
# step: Santa Ana -> Costa Mesa (8.30km)
# step: Costa Mesa -> Huntington Beach (9.40km)
# step: Huntington Beach -> Garden Grove (10.78km)
# step: Garden Grove -> Anaheim (9.13km)
# step: Anaheim -> Fullerton (6.54km)
# step: Fullerton -> Orange (13.10km)
# step: Orange -> Corona (24.99km)
# step: Corona -> Pasadena (62.63km)
# step: Pasadena -> Glendale (10.06km)
# step: Glendale -> Burbank (7.33km)
# step: Burbank -> Victorville (96.93km)
# step: Victorville -> Enterprise (255.31km)
# step: Enterprise -> Spring Valley (9.87km)
# step: Spring Valley -> Paradise (11.44km)
# step: Paradise -> Henderson (11.74km)
# step: Henderson -> Sunrise Manor (18.48km)
# step: Sunrise Manor -> North Las Vegas (12.15km)
# step: North Las Vegas -> Las Vegas (16.86km)
# step: Las Vegas -> Surprise (382.61km)
# step: Surprise -> Phoenix (35.56km)
# step: Phoenix -> Tempe (25.02km)
# step: Tempe -> Chandler (13.72km)
# step: Chandler -> Gilbert (10.93km)
# step: Gilbert -> Mesa (10.43km)
# step: Mesa -> Scottsdale (31.20km)
# step: Scottsdale -> Tucson (190.13km)
# step: Tucson -> Santa Maria (940.50km)
# step: Santa Maria -> Santa Rosa (439.17km)
# step: Santa Rosa -> Reno (278.35km)
# step: Reno -> Sparks (12.12km)
# step: Sparks -> Billings (1144.36km)
# step: Billings -> Fargo (909.58km)
# step: Fargo -> Des Moines (641.39km)
# step: Des Moines -> Cedar Rapids (167.02km)
# step: Cedar Rapids -> Davenport (100.38km)
# step: Davenport -> Peoria (121.62km)
# step: Peoria -> Springfield (109.85km)
# step: Springfield -> Saint Louis (134.70km)
# step: Saint Louis -> Anchorage (4702.93km)
# step: Anchorage -> Honolulu (4476.25km)
# step: Honolulu -> Abilene (5833.59km)

# %% [markdown]
# ## Evolutionary algorithm

# %%
#definisci class individual
@dataclass
class Individual:
    genome: list
    fitness: float = None

    def compute_fitness(self):
        total_distance = 0
        for i in range(len(self.genome) - 1):
            total_distance += DIST_MATRIX[self.genome[i], self.genome[i + 1]]
        total_distance += DIST_MATRIX[self.genome[-1], self.genome[0]]  #torno alla prima città
        self.fitness = 1/total_distance

# %% [markdown]
# ## Parent sel

# %%
def parent_sel_uniform(population):
    return random.choice(population)

def parent_sel_tournament(population, tournament_size=3):
    candidates = random.sample(population, tournament_size)
    return max(candidates, key=lambda ind: ind.fitness)

# %%
def xover(p1, p2):
    size = len(p1.genome)
    start, end = sorted(random.sample(range(1, size), 2))
    child_genome = [None] * size
    child_genome[start:end] = p1.genome[start:end]
    
    current_index = 0
    for gene in p2.genome:
        if gene not in child_genome:
            while child_genome[current_index] is not None:
                current_index += 1
            child_genome[current_index] = gene
            
    return Individual(genome=child_genome)
            

def mutation(individual, ):   #inversion mut
    if np.random.rand() < 0.1:
        idx1, idx2 = random.sample(range(1, len(individual.genome)), 2) 
        if idx1 > idx2:
            idx1, idx2 = idx2, idx1
        individual.genome[idx1:idx2+1] = reversed(individual.genome[idx1:idx2+1])
    return individual

# %% [markdown]
# ## Algortimo

# %% [markdown]
# ### uniform selection

# %%
POPULATION_SIZE = 100
MAX_GENERATIONS = 1000
def genetic_alg( country='Italy'):
    
    population = []
    for _ in range(POPULATION_SIZE):
        unique_cities = random.sample(range(1, len(CITIES)), len(CITIES) - 1)
        genome = [0] + unique_cities 
        population.append(Individual(genome=genome))

    for ind in population:
        ind.compute_fitness()

    for _ in tqdm(range(MAX_GENERATIONS)):
        new_population = []

        while len(new_population) < POPULATION_SIZE:

            #uniform sel
            parent1 = parent_sel_uniform(population)
            parent2 = parent_sel_uniform(population)
            
            # crossover 
            child = xover(parent1, parent2)
            
            # mutation           
            child = mutation(child)
            
            child.compute_fitness()
            new_population.append(child)

        population = new_population
   
    best_individual = max(population, key=lambda ind: ind.fitness)
    return best_individual

# %%
# Run  

for country in countries:

    init(country)
    print(country)
    best_solution = genetic_alg(country)

    best_solution.genome.append(best_solution.genome[0])  # Return to starting city
    tot_distance = compute_tour_distance(best_solution.genome, DIST_MATRIX)
    print(f"Genetic Algorithm with uniform selection, country: {country}")
    print(f"Result:  {len(best_solution.genome) - 1} steps, total length {tot_distance:.2f}km\n")
# Out:
# Russia
# 100%|██████████| 1000/1000 [00:20<00:00, 48.18it/s]
# Genetic Algorithm with uniform selection, country: Russia
# Result:  167 steps, total length 308726.43km
#
# Italy
# 100%|██████████| 1000/1000 [00:02<00:00, 353.72it/s]
# Genetic Algorithm with uniform selection, country: Italy
# Result:  46 steps, total length 16832.64km
#
# Vanuatu
# 100%|██████████| 1000/1000 [00:00<00:00, 1666.14it/s]
# Genetic Algorithm with uniform selection, country: Vanuatu
# Result:  8 steps, total length 1397.64km
#
# China
# 100%|██████████| 1000/1000 [05:38<00:00,  2.95it/s]
# Genetic Algorithm with uniform selection, country: China
# Result:  726 steps, total length 944914.05km
#
# US
# 100%|██████████| 1000/1000 [01:08<00:00, 14.52it/s]
# Genetic Algorithm with uniform selection, country: US
# Result:  326 steps, total length 592699.61km

# %% [markdown]
# ### Tournament selection

# %%
POPULATION_SIZE = 100
MAX_GENERATIONS = 1000
def genetic_alg( country='Italy'):
    
    population = []
    for _ in range(POPULATION_SIZE):
        unique_cities = random.sample(range(1, len(CITIES)), len(CITIES) - 1)
        genome = [0] + unique_cities 
        population.append(Individual(genome=genome))

    for ind in population:
        ind.compute_fitness()

    for _ in tqdm(range(MAX_GENERATIONS)):
        new_population = []

        while len(new_population) < POPULATION_SIZE:

            #tournament sel
            parent1 = parent_sel_tournament(population, 3)  #tournament size = 3
            parent2 = parent_sel_tournament(population, 3)
            
            # crossover 
            child = xover(parent1, parent2)
            
            # mutation           
            child = mutation(child)
            
            child.compute_fitness()
            new_population.append(child)

        population = new_population
   
    best_individual = max(population, key=lambda ind: ind.fitness)
    return best_individual

# %%
# Run  

for country in countries:

    init(country)
    print(country)
    best_solution = genetic_alg(country)

    best_solution.genome.append(best_solution.genome[0])  # Return to starting city
    tot_distance = compute_tour_distance(best_solution.genome, DIST_MATRIX)
    print(f"Genetic Algorithm with tournament seelction with size = 3, country: {country}")
    print(f"Result:  {len(best_solution.genome) - 1} steps, total length {tot_distance:.2f}km\n")
# Out:
# Russia
# 100%|██████████| 1000/1000 [00:20<00:00, 48.96it/s]
# Genetic Algorithm with tournament seelction with size = 3, country: Russia
# Result:  167 steps, total length 50564.93km
#
# Italy
# 100%|██████████| 1000/1000 [00:02<00:00, 337.24it/s]
# Genetic Algorithm with tournament seelction with size = 3, country: Italy
# Result:  46 steps, total length 4259.66km
#
# Vanuatu
# 100%|██████████| 1000/1000 [00:00<00:00, 1126.12it/s]
# Genetic Algorithm with tournament seelction with size = 3, country: Vanuatu
# Result:  8 steps, total length 1345.54km
#
# China
# 100%|██████████| 1000/1000 [05:15<00:00,  3.16it/s]
# Genetic Algorithm with tournament seelction with size = 3, country: China
# Result:  726 steps, total length 337189.47km
#
# US
# 100%|██████████| 1000/1000 [01:08<00:00, 14.57it/s]
# Genetic Algorithm with tournament seelction with size = 3, country: US
# Result:  326 steps, total length 138031.48km
